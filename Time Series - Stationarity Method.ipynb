# %%
import pandas as pd
from nsepy import get_history as gh
import datetime as dt
import yfinance as yf

# %%
import datetime as dt

start = dt.datetime(2021, 7, 1)
end = dt.datetime(2022, 1, 27)
symbol = 'AXISBANK.NS'  # Stock symbol in uppercase

stk_data = yf.download(symbol, start=start, end=end)
stk_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-07-01  750.000000  754.400024  744.500000  746.450012  743.211731
# 2021-07-02  747.599976  752.849976  744.000000  750.650024  747.393555
# 2021-07-05  757.099976  762.000000  753.400024  760.349976  757.051453
# 2021-07-06  757.000000  767.000000  755.200012  758.349976  755.060120
# 2021-07-07  755.900024  764.000000  752.250000  762.900024  759.590454
# ...                ...         ...         ...         ...         ...
# 2022-01-19  725.200012  731.950012  718.700012  729.599976  726.434875
# 2022-01-20  731.049988  737.150024  722.150024  728.900024  725.737854
# 2022-01-21  722.000000  725.250000  708.049988  712.500000  709.409058
# 2022-01-24  715.000000  716.400024  688.200012  704.599976  701.543274
# 2022-01-25  714.000000  755.000000  708.599976  752.200012  748.936768
#
#               Volume
# Date
# 2021-07-01   5695690
# 2021-07-02   3557647
# 2021-07-05   4680089
# 2021-07-06   5529485
# 2021-07-07   3573368
# ...              ...
# 2022-01-19   7746270
# 2022-01-20   8505400
# 2022-01-21  10689060
# 2022-01-24   8812501
# 2022-01-25  38088158
#
# [143 rows x 6 columns]

# %%
stk_data=stk_data[["Open","High","Low","Close"]]
stk_data
# Out:
#                   Open        High         Low       Close
# Date
# 2021-07-01  750.000000  754.400024  744.500000  746.450012
# 2021-07-02  747.599976  752.849976  744.000000  750.650024
# 2021-07-05  757.099976  762.000000  753.400024  760.349976
# 2021-07-06  757.000000  767.000000  755.200012  758.349976
# 2021-07-07  755.900024  764.000000  752.250000  762.900024
# ...                ...         ...         ...         ...
# 2022-01-19  725.200012  731.950012  718.700012  729.599976
# 2022-01-20  731.049988  737.150024  722.150024  728.900024
# 2022-01-21  722.000000  725.250000  708.049988  712.500000
# 2022-01-24  715.000000  716.400024  688.200012  704.599976
# 2022-01-25  714.000000  755.000000  708.599976  752.200012
#
# [143 rows x 4 columns]

# %%
dataset=stk_data

#Start date and end_date
from datetime import date, timedelta
import pandas as pd
start_date = pd.to_datetime("2013-01-01")
end_date = pd.to_datetime("2019-02-04") - timedelta(days=1) #Excluding last

#List of all dates
all_date = pd.date_range(start_date, end_date, freq='d')

# %%
all_date
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10',
#                ...
#                '2019-01-25', '2019-01-26', '2019-01-27', '2019-01-28',
#                '2019-01-29', '2019-01-30', '2019-01-31', '2019-02-01',
#                '2019-02-02', '2019-02-03'],
#               dtype='datetime64[ns]', length=2225, freq='D')

# %%
dummyDate=dataset

# %%
dummyDate
# Out:
#                   Open        High         Low       Close
# Date
# 2021-07-01  750.000000  754.400024  744.500000  746.450012
# 2021-07-02  747.599976  752.849976  744.000000  750.650024
# 2021-07-05  757.099976  762.000000  753.400024  760.349976
# 2021-07-06  757.000000  767.000000  755.200012  758.349976
# 2021-07-07  755.900024  764.000000  752.250000  762.900024
# ...                ...         ...         ...         ...
# 2022-01-19  725.200012  731.950012  718.700012  729.599976
# 2022-01-20  731.049988  737.150024  722.150024  728.900024
# 2022-01-21  722.000000  725.250000  708.049988  712.500000
# 2022-01-24  715.000000  716.400024  688.200012  704.599976
# 2022-01-25  714.000000  755.000000  708.599976  752.200012
#
# [143 rows x 4 columns]

# %%
#DateIndex.index=pd.to_datetime(dataset["Date"],infer_datetime_format=True)
import matplotlib.pyplot as plt
plt.plot(dataset["Close"])

# %%
from pandas import read_csv
from matplotlib import pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(dummyDate["Close"], model='multiplicative')
plt.figure(figsize=(16,5))
result.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 4
#       2 from matplotlib import pyplot as plt
#       3 from statsmodels.tsa.seasonal import seasonal_decompose
# ----> 4 result = seasonal_decompose(dummyDate["Close"], model='multiplicative')
#       5 plt.figure(figsize=(16,5))
#       6 result.plot()
#
# File ~\Documents\anaconda installation\envs\aidl\lib\site-packages\statsmodels\tsa\seasonal.py:167, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     165         period = pfreq
#     166     else:
# --> 167         raise ValueError(
#     168             "You must specify a period or x must be a pandas object with "
#     169             "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#     170         )
#     171 if x.shape[0] < 2 * pfreq:
#     172     raise ValueError(
#     173         f"x must have 2 complete cycles requires {2 * pfreq} "
#     174         f"observations. x only has {x.shape[0]} observation(s)"
#     175     )
#
# ValueError: You must specify a period or x must be a pandas object with a PeriodIndex or a DatetimeIndex with a freq not set to None
